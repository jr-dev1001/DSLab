# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("dataset.csv")

# %%
df.shape
# Out:
# (50, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of    branch  age gen  sub1  sub2  sub3 Bgroup     phn
# 0     cse   20   f    96    41    79      a  766446
# 1     ece   22   m    55    96    37      b  576546
# 2      me   21   m    70    62    40      o  456767
# 3      ce   22   m    37    59    75      o  984457
# 4     eee   19   m    67    32    97      o  435464
# 5      ce   18   f    47    41    48      b  345664
# 6     cse   20   f    63    69    51      a  564731
# 7     cse   23   f    98    77    58      a  256754
# 8     mme   21   m    55    38    84      b  987643
# 9     puc   20   m    31    85    95     ab  853564
# 10   chem   21   m    55    88    96     ab  234656
# 11   chem   22   f    72    60    31      b  685355
# 12    cse   19   m    78    55    98      b  465435
# 13    ece   18   f    67    54    47     ab  856823
# 14    puc   23   m    92    39    99      o  576535
# 15     ce   24   f    96    40    69      o  899676
# ...

# %%
df.dtypes
# Out:
# branch    object
# age        int64
# gen       object
# sub1       int64
# sub2       int64
# sub3       int64
# Bgroup    object
# phn        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['branch', 'age', 'gen', 'sub1', 'sub2', 'sub3', 'Bgroup', 'phn'], dtype='object')

# %%
df.head()
# Out:
#   branch  age gen  sub1  sub2  sub3 Bgroup     phn
# 0    cse   20   f    96    41    79      a  766446
# 1    ece   22   m    55    96    37      b  576546
# 2     me   21   m    70    62    40      o  456767
# 3     ce   22   m    37    59    75      o  984457
# 4    eee   19   m    67    32    97      o  435464

# %%
df.tail()
# Out:
#    branch  age gen  sub1  sub2  sub3 Bgroup     phn
# 45   chem   21   f    91    41    95      b  349063
# 46    eee   22   f    73    76    77      a  580853
# 47    cse   19   f    86    30    73      a  247896
# 48    eee   18   m    97    33    86      a  347989
# 49    ece   19   m    48    76    55     ab  290912

# %%
sns.distplot(df['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.nunique().count
# Out:
# <bound method Series.count of branch     8
# age        8
# gen        2
# sub1      38
# sub2      35
# sub3      36
# Bgroup     4
# phn       50
# dtype: int64>

# %%
df.isnull().sum()
# Out:
# branch    0
# age       0
# gen       0
# sub1      0
# sub2      0
# sub3      0
# Bgroup    0
# phn       0
# dtype: int64

# %% [markdown]
# ##to drop the rows which contains empty cell

# %%
new_df=df.dropna()
new_df=df.dropna(inplace=True)
print(new_df)
# Out:
# None

# %%
for x in df.index:
  if df.loc[x,"branch"]=="cse":
    df.loc[x,"branch"]="IT/CSE"
print(df)
# Out:
#     branch  age gen  sub1  sub2  sub3 Bgroup     phn
# 0   IT/CSE   20   f    96    41    79      a  766446
# 1      ece   22   m    55    96    37      b  576546
# 2       me   21   m    70    62    40      o  456767
# 3       ce   22   m    37    59    75      o  984457
# 4      eee   19   m    67    32    97      o  435464
# 5       ce   18   f    47    41    48      b  345664
# 6   IT/CSE   20   f    63    69    51      a  564731
# 7   IT/CSE   23   f    98    77    58      a  256754
# 8      mme   21   m    55    38    84      b  987643
# 9      puc   20   m    31    85    95     ab  853564
# 10    chem   21   m    55    88    96     ab  234656
# 11    chem   22   f    72    60    31      b  685355
# 12  IT/CSE   19   m    78    55    98      b  465435
# 13     ece   18   f    67    54    47     ab  856823
# 14     puc   23   m    92    39    99      o  576535
# 15      ce   24   f    96    40    69      o  899676
# 16      me   21   m    34    95   100      o  246756
# ...

# %%
for x in df.index:
  if df.loc[x,"branch"]=="cse" and df.loc[x,"gen"]=="m":
    df.drop(x)
print(df)
# Out:
#    branch  age gen  sub1  sub2  sub3 Bgroup     phn
# 0     cse   20   f    96    41    79      a  766446
# 1     ece   22   m    55    96    37      b  576546
# 2      me   21   m    70    62    40      o  456767
# 3      ce   22   m    37    59    75      o  984457
# 4     eee   19   m    67    32    97      o  435464
# 5      ce   18   f    47    41    48      b  345664
# 6     cse   20   f    63    69    51      a  564731
# 7     cse   23   f    98    77    58      a  256754
# 8     mme   21   m    55    38    84      b  987643
# 9     puc   20   m    31    85    95     ab  853564
# 10   chem   21   m    55    88    96     ab  234656
# 11   chem   22   f    72    60    31      b  685355
# 12    cse   19   m    78    55    98      b  465435
# 13    ece   18   f    67    54    47     ab  856823
# 14    puc   23   m    92    39    99      o  576535
# 15     ce   24   f    96    40    69      o  899676
# 16     me   21   m    34    95   100      o  246756
# ...

# %%
sns.pairplot(df)

# %%
df.dropna()
# Out:
#    branch  age gen  sub1  sub2  sub3 Bgroup     phn
# 0     cse   20   f    96    41    79      a  766446
# 1     ece   22   m    55    96    37      b  576546
# 2      me   21   m    70    62    40      o  456767
# 3      ce   22   m    37    59    75      o  984457
# 4     eee   19   m    67    32    97      o  435464
# 5      ce   18   f    47    41    48      b  345664
# 6     cse   20   f    63    69    51      a  564731
# 7     cse   23   f    98    77    58      a  256754
# 8     mme   21   m    55    38    84      b  987643
# 9     puc   20   m    31    85    95     ab  853564
# 10   chem   21   m    55    88    96     ab  234656
# 11   chem   22   f    72    60    31      b  685355
# 12    cse   19   m    78    55    98      b  465435
# 13    ece   18   f    67    54    47     ab  856823
# 14    puc   23   m    92    39    99      o  576535
# 15     ce   24   f    96    40    69      o  899676
# 16     me   21   m    34    95   100      o  246756
# ...

# %%
df.corr()
# Out:
#            age      sub1      sub2      sub3       phn
# age   1.000000  0.188786  0.127042 -0.146165  0.037849
# sub1  0.188786  1.000000 -0.246590  0.057016  0.122089
# sub2  0.127042 -0.246590  1.000000 -0.181404 -0.177595
# sub3 -0.146165  0.057016 -0.181404  1.000000 -0.015922
# phn   0.037849  0.122089 -0.177595 -0.015922  1.000000

# %%
corel=df.corr()
sns.heatmap(corel,xticklabels=corel.columns,yticklabels=corel.columns,annot=True)

# %%
sns.relplot(x="sub1",y="sub2",hue="gen",data=df)

# %%
sns.catplot(x="sub1",kind="box",data=df)
